# %%
import pandas as pd
dane = pd.read_csv("latest.csv")
dane.head()
# Out:
#    developer_name  developer_nip typ_obiektu nazwa_inwestycji    budynek  \
# 0  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 1  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 2  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 3  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 4  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
#
#   numer_lokalu    pietro  pokoje status_name    status_norm  area_usable_m2  \
# 0           10  I Piętro     2.0  rezerwacja  zarezerwowane           33.31
# 1           11  I Piętro     2.0   sprzedane      sprzedane           33.41
# 2           12  I Piętro     2.0   sprzedane      sprzedane           33.69
# 3           13  I Piętro     2.0   sprzedane      sprzedane           33.41
# 4           14  I Piętro     2.0   sprzedane      sprzedane           26.05
#
# ...

# %%
# pokaż mieszkania z > 2 pokoje
dane[dane['pokoje']>2]
# Out:
#      developer_name  developer_nip typ_obiektu nazwa_inwestycji    budynek  \
# 9    PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 22   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 34   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 36   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 47   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 61   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek B
# 73   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek B
# 85   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek B
# 87   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek B
# 99   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek B
# 103  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek C
# ...

# %%
# zrób nowy dataset
maxpokoi = dane[dane['pokoje']>2]
maxpokoi.head()
# Out:
#     developer_name  developer_nip typ_obiektu nazwa_inwestycji    budynek  \
# 9   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 22  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 34  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 36  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 47  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
#
#    numer_lokalu      pietro  pokoje status_name status_norm  area_usable_m2  \
# 9            19   II Piętro     3.0   sprzedane   sprzedane           57.46
# 22           30  III Piętro     3.0   sprzedane   sprzedane           57.46
# 34           41   IV Piętro     3.0   sprzedane   sprzedane           57.46
# 36           43   IV Piętro     3.0       wolne    dostępne           45.37
# 47            8    I Piętro     3.0       wolne    dostępne           57.46
#
# ...

# %%
# sprawdzimy, jak nazywają się inwestycje
maxpokoi['pietro'].unique()
# Out:
# array(['II Piętro', 'III Piętro', 'IV Piętro', 'I Piętro'], dtype=object)

# %%
sprzedane = maxpokoi[maxpokoi['status_norm']=='sprzedane']
wolne = maxpokoi[maxpokoi['status_norm']=='dostępne']

# %%
sprzedane
# Out:
#     developer_name  developer_nip typ_obiektu nazwa_inwestycji    budynek  \
# 9   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 22  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 34  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 61  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek B
# 73  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek B
# 85  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek B
# 87  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek B
#
#    numer_lokalu      pietro  pokoje status_name status_norm  area_usable_m2  \
# 9            19   II Piętro     3.0   sprzedane   sprzedane           57.46
# 22           30  III Piętro     3.0   sprzedane   sprzedane           57.46
# 34           41   IV Piętro     3.0   sprzedane   sprzedane           57.46
# ...

# %%
wolne
# Out:
#      developer_name  developer_nip typ_obiektu nazwa_inwestycji    budynek  \
# 36   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 47   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek A
# 99   PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek B
# 103  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek C
# 115  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek C
# 127  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek C
# 139  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek C
# 141  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek C
# 157  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek D
# 169  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek D
# 181  PM Development     6762594840  mieszkanie    Ecco Panorama  Budynek D
# ...
